# %% [markdown]
# <a href="https://colab.research.google.com/github/altamash7014/Email-classifier/blob/main/bmi_langraph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from langgraph.graph import StateGraph,START,END
from typing import TypedDict

# %%
#define state
# the state we define is actually a dictionary in which we can tell our dtype
class BMIState(TypedDict):
    height_m: float
    weight_kg: float
    bmi: float

# %%
 def calculateBMI(state : BMIState) ->BMIState:
  weight_kg = state['weight_kg']
  height_m = state['height_m']
  bmi = weight_kg/(height_m*height_m)
  state['bmi'] = round(bmi,3)
  return state

# %%
# defining ouy graph

graph = StateGraph(BMIState)

# adding nodes to graph
graph.add_node("calculated BMI",calculateBMI)

# adding edges to our graph
graph.add_edge(START, "calculated BMI")
# compiling graph
graph.add_edge( "calculated BMI", END)

# execution
workflow = graph.compile()

# %%
initial = {'weight_kg': 70, 'height_m': 1.75}

final = workflow.invoke(initial)

print(final)
# Out:
# {'height_m': 1.75, 'weight_kg': 70, 'bmi': 22.857}
